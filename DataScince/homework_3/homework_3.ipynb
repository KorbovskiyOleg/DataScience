# %% [markdown]
# # About Dataset

# %% [markdown]
# ## Context:
# ### Этот синтетический набор медицинских данных был создан для того, чтобы служить ценным ресурсом для любителей науки о данных, машинного обучения и анализа данных. Он предназначен для имитации реальных медицинских данных, позволяя пользователям практиковаться, развивать и демонстрировать свои навыки манипулирования данными и их анализа в контексте отрасли здравоохранения.

# %% [markdown]
# ## Inspiration:
# ### Источником вдохновения для создания этого набора данных является потребность в практических и разнообразных медицинских данных для образовательных и исследовательских целей. Медицинские данные часто являются конфиденциальными и подпадают под действие правил конфиденциальности, что затрудняет доступ к ним для изучения и экспериментов. Чтобы устранить этот пробел, я использовал библиотеку Faker в Python для создания набора данных, который отражает структуру и атрибуты, обычно встречающиеся в медицинских записях. Предоставляя эти синтетические данные, я надеюсь способствовать инновациям, обучению и обмену знаниями в области аналитики здравоохранения.

# %% [markdown]
# ## Dataset Information:
# ### В каждом столбце содержится конкретная информация о пациенте, его поступлении в больницу и оказанных медицинских услугах, что делает этот набор данных подходящим для решения различных задач по анализу данных и моделированию в сфере здравоохранения.

# %%
#### Name: В этом столбце указано имя пациента, связанное с медицинской картой.
#### Age: Возраст пациента на момент поступления, выраженный в годах.
#### Gender: Указывает пол пациента, будь то "Мужчина" или "Женщина".
#### Blood Type: Группа крови пациента, которая может быть одной из распространенных групп крови (например, "А+", "О-" и т.д.).
#### Medical Condition: В этом столбце указывается основное медицинское состояние или диагноз, связанный с пациентом, например "Сахарный диабет", "Гипертония", "Астма" и другие.
#### Date of Admission: дата, когда пациент был госпитализирован в медицинское учреждение.
#### Doctor: Имя врача, ответственного за уход за пациентом во время его госпитализации.
#### Hospital: Определяет медицинское учреждение или больницу, куда был госпитализирован пациент.
#### Insurance Provider: В этом столбце указывается поставщик услуг страхования пациента, который может быть одним из нескольких вариантов, включая "Aetna", "Blue Cross", "Cigna", "UnitedHealthcare" и "Medicare".
#### Billing Amount: Сумма, на которую был выставлен счет за медицинские услуги пациента во время его госпитализации. Выражается в виде числа с плавающей запятой.
#### Room Number: Номер палаты, в которой находился пациент во время его госпитализации.
#### Admission Type: Определяет тип приема, который может быть "Экстренным", "Факультативным" или "Срочным", что отражает обстоятельства приема.
#### Discharge Type: Дата, в которую пациент был выписан из медицинского учреждения, основанная на дате поступления и случайном количестве дней в пределах допустимого диапазона.
#### Medication: Определяет лекарственное средство, назначенное пациенту во время его поступления. В качестве примеров можно привести "Аспирин", "Ибупрофен", "Пенициллин", "парацетамол" и "Липитор".
#### Test Results: Описывает результаты медицинского обследования, проведенного при поступлении пациента. Возможные значения включают "Нормальные", "Ненормальные" или "неубедительные", что указывает на результат теста.

# %% [markdown]
# #### Cценарии использования

# %%
#Разработка и тестирование прогнозных моделей здравоохранения.
#Отработка методов очистки, преобразования и анализа данных.
#Создание визуализаций данных для получения информации о тенденциях в области здравоохранения.
#Изучение и преподавание концепций обработки данных и машинного обучения в контексте здравоохранения.
#Вы можете рассматривать это как многоклассовую классификационную задачу и решить ее для получения результатов теста, которые содержат 3 категории (нормальные, ненормальные и неубедительные).

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('healthcare_dataset.csv')

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df['Name'] = df['Name'].apply(lambda x : x.title())

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %%
age_hist = plt.hist(df['Age'], bins= 10)
age_hist
# Out:
# (array([2443., 6463., 5626., 6569., 5732., 6710., 6563., 5621., 6556.,
#         3217.]),
#  array([13. , 20.6, 28.2, 35.8, 43.4, 51. , 58.6, 66.2, 73.8, 81.4, 89. ]),
#  <BarContainer object of 10 artists>)

# %%
# %pip install gender-guesser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gender_guesser.detector as gender
from tqdm import tqdm

# %%
# не оптимизированная версия (30 минут выполняется!!!!)

#def correct_name_gender(name, current_gender):

    # Извлекаем первое имя
    first_name = name.split()[0]
    
    # Определяем гендер по имени
    gender_detector = gender.Detector()
    detected_gender = gender_detector.get_gender(first_name)
    
    # Преобразуем в наш формат
    gender_map = {
        'male': 'Male',
        'mostly_male': 'Male', 
        'female': 'Female',
        'mostly_female': 'Female'
    }
    
    predicted_gender = gender_map.get(detected_gender, current_gender)
    
    
    return predicted_gender
     
tqdm.pandas()

df['Gender_corrected'] = df.progress_apply(
    lambda row: correct_name_gender(row['Name'], row['Gender']), axis=1
)
# Out:
#   Cell In[13], line 6
#     first_name = name.split()[0]
#     ^
# IndentationError: unexpected indent

# %%
# Оптимизированная версия

def fast_bulk_gender_correction(df):
    import gender_guesser.detector as gender
    from tqdm import tqdm
    
    # Обрабатываем только уникальные имена (их намного меньше)
    first_names = df['Name'].str.split().str[0].str.title()
    unique_names = first_names.unique()
    
    print(f"Обрабатываем {len(unique_names)} уникальных имен вместо {len(df)} записей...")
    
    detector = gender.Detector()
    gender_map = {}
    
    for name in tqdm(unique_names):
        detected = detector.get_gender(name)
        gender_map[name] = 'Female' if detected in ['female', 'mostly_female'] else 'Male'
    
    # Применяем ко всему датафрейму
    df['Gender_corrected'] = first_names.map(gender_map)
    df['Gender_corrected'] = df['Gender_corrected'].fillna(df['Gender'])
    
    return df
df = fast_bulk_gender_correction(df)
# Out:
# Обрабатываем 695 уникальных имен вместо 55500 записей...
# 100%|██████████| 695/695 [00:00<00:00, 196948.94it/s]

# %%
# Посмотрим на результаты
print("Статистика по изменениям:")
print(f"Всего записей: {len(df)}")
print(f"Изменено гендеров: {(df['Gender'] != df['Gender_corrected']).sum()}")
# Out:
# Статистика по изменениям:
# Всего записей: 55500
# Изменено гендеров: 27691

# %%
mismatches = df[df['Gender'] != df['Gender_corrected']]
print(f"\nПримеры изменений (первые 10):")
for i, row in mismatches.head(10).iterrows():
    print(f"{row['Name']:25} | {row['Gender']} → {row['Gender_corrected']}")
# Out:
# Примеры изменений (первые 10):
# Leslie Terry              | Male → Female
# Danny Smith               | Female → Male
# Andrew Watts              | Female → Male
# Emily Johnson             | Male → Female
# Edward Edwards            | Female → Male
# Jasmine Aguilar           | Male → Female
# Christopher Berg          | Female → Male
# Michelle Daniels          | Male → Female
# Aaron Martinez            | Female → Male
# Connor Hansen             | Female → Male

# %%
df['Gender'] = df['Gender_corrected']

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62  Female         A+           Obesity
# 2            Danny Smith   76    Male         A-           Obesity
# 3           Andrew Watts   28    Male         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43  Female         O-         Arthritis
# 55499       James Garcia   53    Male         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      28677
# Female    26823
# Name: count, dtype: int64

# %%
# признак Blood Type

# %%
df['Blood Type'].value_counts()
# Out:
# Blood Type
# A-     6969
# A+     6956
# AB+    6947
# AB-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64

# %%
bt_hist = plt.hist(df['Blood Type'], bins=15)
plt.show()

# %%
# Создаем кросс-таблицу
cross_tab = pd.crosstab(df['Blood Type'], df['Gender'])

# Сортируем группы крови в логическом порядке
blood_order = ['A+', 'A-', 'B+', 'B-', 'AB+', 'AB-', 'O+', 'O-']
cross_tab = cross_tab.reindex(blood_order)

plt.figure(figsize=(12, 6))
cross_tab.plot(kind='bar', figsize=(12, 6), color=['lightpink', 'lightblue'])
plt.title('Распределение групп крови по полу', fontsize=14)
plt.xlabel('Группа крови', fontsize=12)
plt.ylabel('Количество пациентов', fontsize=12)
plt.legend(title='Пол', labels=['Женщины', 'Мужчины'])
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Признак Medicial Condition

# %%
df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
# Создаем кросс-таблицу
cross_tab = pd.crosstab(df['Medical Condition'], df['Gender'])

# Сортируем диагно в логическом порядке
blood_order = ['Arthritis', 'Diabetes', 'Hypertension', 'Obesity', 'Cancer', 'Asthma']
cross_tab = cross_tab.reindex(blood_order)

plt.figure(figsize=(12, 6))
cross_tab.plot(kind='bar', figsize=(12, 6), color=['lightpink', 'lightblue'])
plt.title('Распределение диагнозов по полу', fontsize=14)
plt.xlabel('Диагноз', fontsize=12)
plt.ylabel('Количество пациентов', fontsize=12)
plt.legend(title='Пол', labels=['Женщины', 'Мужчины'])
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Создаем кросс-таблицу
cross_tab = pd.crosstab(df['Medical Condition'], df['Blood Type'])

# Сортируем диагно в логическом порядке
blood_order = ['Arthritis', 'Diabetes', 'Hypertension', 'Obesity', 'Cancer', 'Asthma']
cross_tab = cross_tab.reindex(blood_order)

plt.figure(figsize=(12, 6))
cross_tab.plot(kind='bar', figsize=(12, 6), color=['pink', 'blue', 'green','red','yellow','purple','brown','orange'])
plt.title('Распределение диагнозов по группе крови', fontsize=14)
plt.xlabel('Диагноз', fontsize=12)
plt.ylabel('Количество пациентов', fontsize=12)
plt.legend(title='Группа крови', labels=['A+', 'A-','B+','B-','AB+','AB-','O+','O-'])
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Сортируем диагнозы
condition_order = ['Arthritis', 'Asthma', 'Cancer', 'Diabetes', 'Hypertension', 'Obesity']
blood_order = ['A+', 'A-', 'B+', 'B-', 'AB+', 'AB-', 'O+', 'O-']



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Мужчины
male_data = pd.crosstab(df[df['Gender'] == 'Male']['Medical Condition'], 
                       df[df['Gender'] == 'Male']['Blood Type'])
male_data = male_data.reindex(condition_order)
sns.heatmap(male_data, annot=True, fmt='d', cmap='Blues', ax=ax1, 
            cbar_kws={'label': 'Количество пациентов'})
ax1.set_title('МУЖЧИНЫ: Распределение диагнозов по группе крови')
ax1.set_xlabel('Группа крови')
ax1.set_ylabel('Диагноз')

# Женщины
female_data = pd.crosstab(df[df['Gender'] == 'Female']['Medical Condition'], 
                         df[df['Gender'] == 'Female']['Blood Type'])
female_data = female_data.reindex(condition_order)
sns.heatmap(female_data, annot=True, fmt='d', cmap='Reds', ax=ax2,
            cbar_kws={'label': 'Количество пациентов'})
ax2.set_title('ЖЕНЩИНЫ: Распределение диагнозов по группе крови')
ax2.set_xlabel('Группа крови')
ax2.set_ylabel('Диагноз')

plt.tight_layout()
plt.show()

# %%
# Признак Date of Abmission

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])

# %%
df['Date of Admission'].min()
# Out:
# Timestamp('2019-05-08 00:00:00')

# %%
df['Date of Admission'].max()
# Out:
# Timestamp('2024-05-07 00:00:00')

# %%
df['Date of Admission'].unique()
# Out:
# <DatetimeArray>
# ['2024-01-31 00:00:00', '2019-08-20 00:00:00', '2022-09-22 00:00:00',
#  '2020-11-18 00:00:00', '2022-09-19 00:00:00', '2023-12-20 00:00:00',
#  '2020-11-03 00:00:00', '2021-12-28 00:00:00', '2020-07-01 00:00:00',
#  '2021-05-23 00:00:00',
#  ...
#  '2019-06-29 00:00:00', '2019-10-07 00:00:00', '2022-11-30 00:00:00',
#  '2023-12-22 00:00:00', '2024-01-26 00:00:00', '2023-02-27 00:00:00',
#  '2022-02-18 00:00:00', '2019-05-31 00:00:00', '2023-10-12 00:00:00',
#  '2021-03-14 00:00:00']
# Length: 1827, dtype: datetime64[ns]

# %%
df['Date of Admission'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Name: Date of Admission, Length: 55500, dtype: bool

# %%
# Извлекаем год, месяц, день недели
df['Admission_Year'] = df['Date of Admission'].dt.year
df['Admission_Month'] = df['Date of Admission'].dt.month
df['Admission_DayOfWeek'] = df['Date of Admission'].dt.day_name()


# Распределение по годам
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
year_counts = df['Admission_Year'].value_counts().sort_index()
year_counts.plot(kind='bar', color='skyblue')
plt.title('Количество поступлений по годам')
plt.xlabel('Год')
plt.ylabel('Количество поступлений')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
month_counts = df['Admission_Month'].value_counts().sort_index()
month_names = ['Янв', 'Фев', 'Мар', 'Апр', 'Май', 'Июн', 
               'Июл', 'Авг', 'Сен', 'Окт', 'Ноя', 'Дек']
month_counts.index = month_names
month_counts.plot(kind='bar', color='lightcoral')
plt.title('Количество поступлений по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Количество поступлений')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Порядок дней недели
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_names_ru = ['Понедельник', 'Вторник', 'Среда', 'Четверг', 'Пятница', 'Суббота', 'Воскресенье']

day_counts = df['Admission_DayOfWeek'].value_counts()
day_counts = day_counts.reindex(day_order)
day_counts.index = day_names_ru

plt.figure(figsize=(10, 6))
day_counts.plot(kind='bar', color='lightgreen')
plt.title('Количество поступлений по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество поступлений')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
# Анализ по типу госпитализации
admission_by_type = pd.crosstab(df['Admission_Month'], df['Admission Type'])
admission_by_type.index = month_names

plt.figure(figsize=(12, 6))
admission_by_type.plot(kind='bar', stacked=True)
plt.title('Тип госпитализации по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Количество поступлений')
plt.legend(title='Тип госпитализации')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Топ дней по количеству поступлений
print("=== ТОП-20 ДНЕЙ ПО КОЛИЧЕСТВУ ПОСТУПЛЕНИЙ ===")
daily_admissions = df['Date of Admission'].value_counts().head(20)

plt.figure(figsize=(14, 6))
daily_admissions.plot(kind='bar', color='orange')
plt.title('Топ-20 дней с наибольшим количеством поступлений')
plt.xlabel('Дата')
plt.ylabel('Количество поступлений')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# === ТОП-20 ДНЕЙ ПО КОЛИЧЕСТВУ ПОСТУПЛЕНИЙ ===

# %%
print("Даты с наибольшим количеством поступлений:")
for date, count in daily_admissions.head(10).items():
    print(f"{date.strftime('%Y-%m-%d')}: {count} поступлений")
# Out:
# Даты с наибольшим количеством поступлений:
# 2024-03-16: 50 поступлений
# 2022-07-24: 49 поступлений
# 2020-10-22: 49 поступлений
# 2021-12-28: 48 поступлений
# 2021-01-03: 48 поступлений
# 2020-04-03: 48 поступлений
# 2022-07-01: 47 поступлений
# 2023-08-10: 47 поступлений
# 2019-11-04: 47 поступлений
# 2022-01-09: 47 поступлений

# %%
# Динамика поступлений по заболеваниям
disease_monthly = df.groupby(['Admission_Month', 'Medical Condition']).size().unstack(fill_value=0)
disease_monthly.index = month_names

plt.figure(figsize=(14, 8))
disease_monthly.plot(kind='line', marker='o', figsize=(14, 8))
plt.title('Динамика поступлений по заболеваниям по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Количество поступлений')
plt.legend(title='Заболевание', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Динамика поступлений по заболеваниям - ГИСТОГРАММА
disease_monthly = df.groupby(['Admission_Month', 'Medical Condition']).size().unstack(fill_value=0)
disease_monthly.index = month_names

plt.figure(figsize=(14, 8))
disease_monthly.plot(kind='bar', figsize=(14, 8))
plt.title('Распределение поступлений по заболеваниям по месяцам', fontsize=14)
plt.xlabel('Месяц', fontsize=12)
plt.ylabel('Количество поступлений', fontsize=12)
plt.legend(title='Заболевание', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(disease_monthly.T, annot=True, fmt='d', cmap='YlOrRd', 
            cbar_kws={'label': 'Количество поступлений'})
plt.title('Heatmap: Поступления по заболеваниям и месяцам', fontsize=14)
plt.xlabel('Месяц')
plt.ylabel('Заболевание')
plt.tight_layout()
plt.show()

# %%
# Добавляем кварталы
df['Admission_Quarter'] = df['Date of Admission'].dt.quarter

quarter_counts = df['Admission_Quarter'].value_counts().sort_index()
quarter_names = ['1 кв', '2 кв', '3 кв', '4 кв']

plt.figure(figsize=(8, 6))
plt.pie(quarter_counts.values, labels=quarter_names, autopct='%1.1f%%', 
        colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'])
plt.title('Распределение поступлений по кварталам')
plt.axis('equal')
plt.show()

# %%
# Фокусируемся на топ заболеваниях
top_diseases = df['Medical Condition'].value_counts().head(3).index
disease_monthly_top = disease_monthly[top_diseases]

plt.figure(figsize=(12, 6))
disease_monthly_top.plot(kind='bar', figsize=(12, 6))
plt.title('Топ-4 заболевания: распределение поступлений по месяцам', fontsize=14)
plt.xlabel('Месяц', fontsize=12)
plt.ylabel('Количество поступлений', fontsize=12)
plt.legend(title='Заболевание')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()

for i, disease in enumerate(diseases):
    if i < len(axes):
        # Фильтруем по заболеванию
        disease_df = df[df['Medical Condition'] == disease]
        
        # Создаем кросс-таблицу
        cross_tab = pd.crosstab(disease_df['Admission_Year'], disease_df['Gender'])
        
        # Строим график
        cross_tab.plot(kind='bar', ax=axes[i], color=['lightpink', 'lightblue'])
        axes[i].set_title(disease, fontsize=14, fontweight='bold')
        axes[i].set_xlabel('Год')
        axes[i].set_ylabel('Количество пациентов')
        axes[i].legend(['Женщины', 'Мужчины'])
        axes[i].tick_params(axis='x', rotation=45)
        axes[i].grid(axis='y', alpha=0.3)

# Удаляем пустые subplots
for i in range(len(diseases), len(axes)):
    fig.delaxes(axes[i])

plt.suptitle('Динамика заболеваний по годам и полу', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.subplots_adjust(top=0.93)
plt.show()
